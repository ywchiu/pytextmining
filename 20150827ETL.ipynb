# %%
a = 3
print a
# Out:
# 3

# %%
import requests
res = requests.get('http://www.appledaily.com.tw/realtimenews/section/new/')
#print res.text

# %%
import requests
payload ={
'StartStation':'977abb69-413a-4ccf-a109-0272c24fd490',
'EndStation':'fbd828d8-b1da-4b06-a3bd-680cdca4d2cd',
'SearchDate':'2015/08/27',
'SearchTime':'10:30',
'SearchWay':'DepartureInMandarin'
}

res  = requests.post('https://www.thsrc.com.tw/tw/TimeTable/SearchResult', data = payload)
print res.text
# Out:
# <!DOCTYPE html>
# <html lang="zh-tw">
#
#
#
# <meta charset="utf-8" />
# <link rel="shortcut icon" href="/Content/favicon/favicon.ico" />
# <!--<meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=no, minimum-scale=1.0, maximum-scale=1.0" />-->
# <meta name="keywords" content="高鐵,快速,旅遊假期,遊玩">
# <meta name="description" content="台灣高鐵連結台灣南北主要城市，我們不只是交通運輸業，更是推動台灣­前進的服務業；我們代表的不僅只是速度，而是速度所帶來的現代生活新態度；我們以更文明的旅行體驗，成為你實現夢想的助力，台灣高鐵，實踐台灣新生活。">
# <meta name="author" content="mi70 uni-net" />
#
#
#     <meta http-equiv="cache-control" content="private">
#
#
# <!--Facebook SEO start-->
#
# <meta property="og:title" content="台灣高鐵" />
# <meta property="og:url" content="http://www.thsrc.com.tw/" />
# <meta property="og:image" content="http://www.thsrc.com.tw/Content/logo.jpg" />
# <!--Facebook SEO end-->
#
# <!--Google +1 start-->
# <meta itemprop="name" content="台灣高鐵" />
# ...

# %%
from bs4 import BeautifulSoup as bs
html_sample = ' \
<html> \
 <body> \
 <h1 id="title">Hello World</h1> \
 <a href="#" class="link">This is link1</a> \
 <a href="# link2" class="link">This is link2</a> \
 </body> \
 </html>'

soup = bs(html_sample)
print soup.text
print soup.contents
# Out:
#    Hello World This is link1 This is link2
# [u' ', <html> <body> <h1 id="title">Hello World</h1> <a class="link" href="#">This is link1</a> <a class="link" href="# link2">This is link2</a> </body> </html>]

# %%
#print soup.select('a')
for a in soup.select('a'):
    print a.text
# Out:
# This is link1
# This is link2

# %%
#id="title"
ele =  soup.select('#title')
print ele
print ele[0]
print ele[0].text
# Out:
# [<h1 id="title">Hello World</h1>]
# <h1 id="title">Hello World</h1>
# Hello World

# %%
#class="link"
ele =  soup.select('.link')
print ele
print ele[0]
print ele[1]
# Out:
# [<a class="link" href="#">This is link1</a>, <a class="link" href="# link2">This is link2</a>]
# <a class="link" href="#">This is link1</a>
# <a class="link" href="# link2">This is link2</a>

# %%
for c in ele:
    print type(c)
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://www.ptt.cc/bbs/Soft_Job/index.html', verify=False)
#print dir(res)
print res.text
# Out:
# C:\Python27\lib\site-packages\requests\packages\urllib3\util\ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# C:\Python27\lib\site-packages\requests\packages\urllib3\connectionpool.py:768: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8" />
#
#
# <meta name="viewport" content="width=device-width">
#
# <title>看板 Soft_Job 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/bbs-common.css" />
# ...

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://www.ptt.cc/bbs/Soft_Job/index.html', verify=False)
soup = BeautifulSoup(res.text)
for ent in soup.select('.r-ent'):
    print ent.select('.author')[0].text.strip(), ent.select('.title')[0].text.strip(), ent.select('.date')[0].text.strip()
# Out:
# C:\Python27\lib\site-packages\requests\packages\urllib3\util\ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# C:\Python27\lib\site-packages\requests\packages\urllib3\connectionpool.py:768: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# derecklin [徵才] 愛搜科技誠徵JAVA後端工程師 8/26
# abola921 Re: [討論] 2015 HackNTU 討論 8/26
# hsundo 關於Python 8/26
# changyuheng Re: [討論] 程式被主管指派他人對外發表! 8/26
# jenlii [情報] 8/28@南軟 科技業徵才活動(yahoo/關貿等) 8/27
# changyuheng Re: Re: [討論] 用Git有什麼缺點? 8/27
# Clarity Fw: [北部]臺灣師範大學 科技部專任助理 Android程式設計人員 8/27
# ...

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('http://www.appledaily.com.tw/realtimenews/section/new/')
#print res.text

# %%
soup = BeautifulSoup(res.text)
for news in soup.select('.rtddt'):
    title =  news.select('h1')[0].text 
    category = news.select('h2')[0].text
    time = news.select('time')[0].text
    url = 'http://www.appledaily.com.tw'+ news.select('a')[0]['href']
    #print title, category, time, url

# %%
import re
for news in soup.select('.rtddt'):    
    main = news.select('h1')[0].text
    m = re.match('(.*)\((\d+)\)',main)
    if m:
        title = m.group(1)
        popularity = int(m.group(2))
        print title, popularity
# Out:
# 【更新】李濤：恐龍家長　讓教育基層挫折 1630
# 登革熱一日新增229例　慎防交叉感染 0
# 【更新】富雷荷提紅不讓　9局皇家5：8金... 31077
# 統合視導累死基層　地方向中央開砲 0
# 波多野悠遊卡爭議　許常德：又不是愛國獎券 363
# UN矮化稱台灣是中國一省　外交部：不接受 104
# 作品遭抄襲　漫畫家蕭言中怒提告 1841
# 你找不到的A片　「他」都聞的到 1065
# 高國華補教人生再展開　這次1對19人 1111
# 20年前的麥當勞　餐盤竟這樣處理 1801
# 消費信心跌　逾5成民眾覺非股票投資時機 0
# 波多野悠遊卡用舊照 　日本公司、經紀人鞠... 13421
# 【更新】人行再放水　陸、港股勁揚 20065
# 特力增建桃園倉庫 　年省1800萬租金 294
# 阿伯野蠻搶車位　網友：歡迎來台中搶 2661
# 最年輕的SBL浪人陳則語　3年換3隊 830
# 【財訊】當台積電淪為外資提款機... 1172
# 視帝的爸今年入圍　蒙古親駱駝自嗨 531
# 雨不停　18縣市發豪雨、大雨特報　11760
# GD傳分手　掰了混血女模 4902
# 虎王韋蘭德1安打完封　裸照風波後最好一戰 1514
# 日月明功虐死高中生　女教主判13年 2803
# 你吃螞蟻！？　60元便當招待大螞蟻 2791
# 填補寂寞心 貓咪呼嚕聲生產器 836
# 美瘋狂男子　拿狗當流星錘襲警 970
# 重現尖叫瓶尿袋  要插電才能充 1621
# App搶客　半價吃台南蝦捲 923
# 100克小幫手　會掃又能翻 961
# 免自拍棒  加一顆就OK 2933
# 8款不良貓星人　愈壞愈惹人愛　2130
