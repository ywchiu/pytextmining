# %%
a = 3
print a
# Out:
# 3

# %%
import requests
res = requests.get('http://www.appledaily.com.tw/realtimenews/section/new/')
#print res.text

# %%
import requests
payload ={
'StartStation':'977abb69-413a-4ccf-a109-0272c24fd490',
'EndStation':'fbd828d8-b1da-4b06-a3bd-680cdca4d2cd',
'SearchDate':'2015/08/27',
'SearchTime':'10:30',
'SearchWay':'DepartureInMandarin'
}

res  = requests.post('https://www.thsrc.com.tw/tw/TimeTable/SearchResult', data = payload)
print res.text
# Out:
# <!DOCTYPE html>
# <html lang="zh-tw">
#
#
#
# <meta charset="utf-8" />
# <link rel="shortcut icon" href="/Content/favicon/favicon.ico" />
# <!--<meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=no, minimum-scale=1.0, maximum-scale=1.0" />-->
# <meta name="keywords" content="高鐵,快速,旅遊假期,遊玩">
# <meta name="description" content="台灣高鐵連結台灣南北主要城市，我們不只是交通運輸業，更是推動台灣­前進的服務業；我們代表的不僅只是速度，而是速度所帶來的現代生活新態度；我們以更文明的旅行體驗，成為你實現夢想的助力，台灣高鐵，實踐台灣新生活。">
# <meta name="author" content="mi70 uni-net" />
#
#
#     <meta http-equiv="cache-control" content="private">
#
#
# <!--Facebook SEO start-->
#
# <meta property="og:title" content="台灣高鐵" />
# <meta property="og:url" content="http://www.thsrc.com.tw/" />
# <meta property="og:image" content="http://www.thsrc.com.tw/Content/logo.jpg" />
# <!--Facebook SEO end-->
#
# <!--Google +1 start-->
# <meta itemprop="name" content="台灣高鐵" />
# ...

# %%
from bs4 import BeautifulSoup as bs
html_sample = ' \
<html> \
 <body> \
 <h1 id="title">Hello World</h1> \
 <a href="#" class="link">This is link1</a> \
 <a href="# link2" class="link">This is link2</a> \
 </body> \
 </html>'

soup = bs(html_sample)
print soup.text
print soup.contents
# Out:
#    Hello World This is link1 This is link2
# [u' ', <html> <body> <h1 id="title">Hello World</h1> <a class="link" href="#">This is link1</a> <a class="link" href="# link2">This is link2</a> </body> </html>]

# %%
#print soup.select('a')
for a in soup.select('a'):
    print a.text
# Out:
# This is link1
# This is link2

# %%
#id="title"
ele =  soup.select('#title')
print ele
print ele[0]
print ele[0].text
# Out:
# [<h1 id="title">Hello World</h1>]
# <h1 id="title">Hello World</h1>
# Hello World

# %%
#class="link"
ele =  soup.select('.link')
print ele
print ele[0]
print ele[1]
# Out:
# [<a class="link" href="#">This is link1</a>, <a class="link" href="# link2">This is link2</a>]
# <a class="link" href="#">This is link1</a>
# <a class="link" href="# link2">This is link2</a>

# %%
for c in ele:
    print type(c)
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://www.ptt.cc/bbs/Soft_Job/index.html', verify=False)
#print dir(res)
print res.text
# Out:
# C:\Python27\lib\site-packages\requests\packages\urllib3\util\ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# C:\Python27\lib\site-packages\requests\packages\urllib3\connectionpool.py:768: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8" />
#
#
# <meta name="viewport" content="width=device-width">
#
# <title>看板 Soft_Job 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/bbs-common.css" />
# ...

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://www.ptt.cc/bbs/Soft_Job/index.html', verify=False)
soup = BeautifulSoup(res.text)
for ent in soup.select('.r-ent'):
    print ent.select('.author')[0].text.strip(), ent.select('.title')[0].text.strip(), ent.select('.date')[0].text.strip()
# Out:
# C:\Python27\lib\site-packages\requests\packages\urllib3\util\ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# C:\Python27\lib\site-packages\requests\packages\urllib3\connectionpool.py:768: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# derecklin [徵才] 愛搜科技誠徵JAVA後端工程師 8/26
# abola921 Re: [討論] 2015 HackNTU 討論 8/26
# hsundo 關於Python 8/26
# changyuheng Re: [討論] 程式被主管指派他人對外發表! 8/26
# jenlii [情報] 8/28@南軟 科技業徵才活動(yahoo/關貿等) 8/27
# changyuheng Re: Re: [討論] 用Git有什麼缺點? 8/27
# Clarity Fw: [北部]臺灣師範大學 科技部專任助理 Android程式設計人員 8/27
# ...

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('http://www.appledaily.com.tw/realtimenews/section/new/')
#print res.text

# %%
soup = BeautifulSoup(res.text)
for news in soup.select('.rtddt'):
    title =  news.select('h1')[0].text 
    category = news.select('h2')[0].text
    time = news.select('time')[0].text
    url = 'http://www.appledaily.com.tw'+ news.select('a')[0]['href']
    #print title, category, time, url

# %%
import re
for news in soup.select('.rtddt'):    
    main = news.select('h1')[0].text
    m = re.match('(.*)\((\d+)\)',main)
    if m:
        title = m.group(1)
        popularity = int(m.group(2))
        print title, popularity
# Out:
# 【更新】李濤：恐龍家長　讓教育基層挫折 1630
# 登革熱一日新增229例　慎防交叉感染 0
# 【更新】富雷荷提紅不讓　9局皇家5：8金... 31077
# 統合視導累死基層　地方向中央開砲 0
# 波多野悠遊卡爭議　許常德：又不是愛國獎券 363
# UN矮化稱台灣是中國一省　外交部：不接受 104
# 作品遭抄襲　漫畫家蕭言中怒提告 1841
# 你找不到的A片　「他」都聞的到 1065
# 高國華補教人生再展開　這次1對19人 1111
# 20年前的麥當勞　餐盤竟這樣處理 1801
# 消費信心跌　逾5成民眾覺非股票投資時機 0
# 波多野悠遊卡用舊照 　日本公司、經紀人鞠... 13421
# 【更新】人行再放水　陸、港股勁揚 20065
# 特力增建桃園倉庫 　年省1800萬租金 294
# 阿伯野蠻搶車位　網友：歡迎來台中搶 2661
# 最年輕的SBL浪人陳則語　3年換3隊 830
# 【財訊】當台積電淪為外資提款機... 1172
# 視帝的爸今年入圍　蒙古親駱駝自嗨 531
# 雨不停　18縣市發豪雨、大雨特報　11760
# GD傳分手　掰了混血女模 4902
# 虎王韋蘭德1安打完封　裸照風波後最好一戰 1514
# 日月明功虐死高中生　女教主判13年 2803
# 你吃螞蟻！？　60元便當招待大螞蟻 2791
# 填補寂寞心 貓咪呼嚕聲生產器 836
# 美瘋狂男子　拿狗當流星錘襲警 970
# 重現尖叫瓶尿袋  要插電才能充 1621
# App搶客　半價吃台南蝦捲 923
# 100克小幫手　會掃又能翻 961
# 免自拍棒  加一顆就OK 2933
# 8款不良貓星人　愈壞愈惹人愛　2130

# %%
soup = BeautifulSoup(res.text)
for news in soup.select('.rtddt'):
    title =  news.select('h1')[0].text 
    category = news.select('h2')[0].text
    time = news.select('time')[0].text
    url = 'http://www.appledaily.com.tw'+ news.select('a')[0]['href']
    #print title, category, time, url

# %%
import requests
from bs4 import BeautifulSoup
import re
section = requests.get('http://www.appledaily.com.tw/realtimenews/section/new/1')
soup = BeautifulSoup(section.text)
domain = 'http://www.appledaily.com.tw'
newsary = []
for news in soup.select('.rtddt'):    
    main = news.select('h1')[0].text
    m = re.match('(.*)\((\d+)\)',main)
    if m:
        title = m.group(1)
        popularity = int(m.group(2))
    category = news.select('h2')[0].text 
    time = news.select('time')[0].text 
    url = domain + news.select('a')[0]['href']
    dic = {'title': title, 'popularity':popularity,'category':category, 'time':time, 'url':url}
    newsary.append(dic)
#print newsary

# %%
import requests
from bs4 import BeautifulSoup
import re
domain = 'http://www.appledaily.com.tw'

newsary = []
appleurl = 'http://www.appledaily.com.tw/realtimenews/section/new/%d'
for page in range(1,20):
    section = requests.get(appleurl%(page))
    soup = BeautifulSoup(section.text)
    for news in soup.select('.rtddt'):    
        main = news.select('h1')[0].text
        m = re.match('(.*)\((\d+)\)',main)
        if m:
            title = m.group(1)
            popularity = int(m.group(2))
        category = news.select('h2')[0].text 
        time = news.select('time')[0].text 
        url = domain + news.select('a')[0]['href']
        dic = {'title': title, 'popularity':popularity,'category':category, 'time':time, 'url':url}
        #print title
        newsary.append(dic)

# %%
import requests
from bs4 import BeautifulSoup

domain = 'http://www.appledaily.com.tw'

newsary = []
appleurl = 'http://www.appledaily.com.tw/realtimenews/section/new/%d'
for page in range(1,20):
    section = requests.get(appleurl%(page))

# %%
import requests
from bs4 import BeautifulSoup
import re
section = requests.get('http://www.appledaily.com.tw/realtimenews/section/new/1')
soup = BeautifulSoup(section.text)
domain = 'http://www.appledaily.com.tw'
newsary = []
for news in soup.select('.rtddt'):    
    main = news.select('h1')[0].text
    m = re.match('(.*)\((\d+)\)',main)
    if m:
        title = m.group(1)
        popularity = int(m.group(2))
    category = news.select('h2')[0].text 
    time = news.select('time')[0].text 
    url = domain + news.select('a')[0]['href']
    dic = {'title': title, 'popularity':popularity,'category':category, 'time':time, 'url':url}
    newsary.append(dic)
#print newsary

# %%
print len(newsary)
# Out:
# 571

# %%
print newsary[0]['title']
# Out:
# ​撞死闖紅燈騎士　男無肇責不起訴

# %%
import pandas as pd
newspd = pd.DataFrame(newsary)
newspd.head()
# Out:
#   category  popularity   time             title  \
# 0       蝷暹�           0  11:49  ���甇駁�蝝��擉�ㄚ����∟�鞎砌�韏瑁迄
# 1       �踵祥           0  11:49  隞�獐���嚗��P�芸旦�啣�銝剝�頠��擳�
# 2       鞎∠�           0  11:49   暺���勗膝嚗���游�銝剖�蝬��憭芣�閫�
# 3       �嫣�           0  11:49   暺���勗膝嚗���游�銝剖�蝬��憭芣�閫�
# 4       蝷暹�           0  11:47    �踹洶�粹�瘣��������銝��擳�楝
#
#                                                  url
# 0  http://www.appledaily.com.tw/realtimenews/arti...
# 1  http://www.appledaily.com.tw/realtimenews/arti...
# 2  http://www.appledaily.com.tw/realtimenews/arti...
# 3  http://www.appledaily.com.twhttp://www.appleda...
# 4  http://www.appledaily.com.tw/realtimenews/arti...

# %%
newspd.sort(['popularity'], ascending=False).head()
# Out:
#     category  popularity   time                title  \
# 522       蝷暹�      325628  16:40    7�砍洶�����蝞晞����鈭箏����蝡��
# 456       憡��      214035  17:30     憟喟��曇�憍瑕援憯��甇∪��������嗚�
# 247       ���      200810  22:36  ����啜��曉��湔�閮芸����2閮���剜�畾箸香
# 481       ��暑      173451  17:15   瘜Ｗ����銵���������祉��亦�A�����
# 420       ��暑      162885  18:08      ����������踵�皜∠���遛皛踵���
#
#                                                    url
# 522  http://www.appledaily.com.tw/realtimenews/arti...
# 456  http://www.appledaily.com.tw/realtimenews/arti...
# 247  http://www.appledaily.com.tw/realtimenews/arti...
# 481  http://www.appledaily.com.tw/realtimenews/arti...
# 420  http://www.appledaily.com.tw/realtimenews/arti...

# %%
df1 = newspd.groupby(['category'], sort=False)['popularity'].max()
print df1
# Out:
# category
# 社會     325628
# 政治      75564
# 財經      97332
# 特企          0
# 生活     173451
# 國際     200810
# 動物      86155
# 娛樂     214035
# 時尚      13199
# 搜奇      64200
# 體育      59852
# FUN     22245
# 瘋啥      17554
# 正妹     160628
# 論壇      17405
# 地產      11574
# Name: popularity, dtype: int64

# %%
idx = newspd.groupby(['category'])['popularity'].transform(max) == newspd['popularity']

# %%
newspd[idx]
# Out:
#     category  popularity   time                    title  \
# 3         �嫣�           0  11:49          暺���勗膝嚗���游�銝剖�蝬��憭芣�閫�
# 47        擃��       59852  10:58  ����啜�5�澆�憯��頧����振�����捕蝯�迫��..
# 158       鞎∠�       97332  04:38  ����啜����摰Ｘ�蝛箄◤�������⊥�瞍�19...
# 161       ���       64200  03:52      �荔�瘝���啣之璅���������喳��函�憌�僥皛�
# 178      FUN       22245  00:49       27摰嗆�頠����遛��漲���摨���荔撚嚗選撚
# 215       甇�此      160628  00:07     AV憟喳��嗡�40摨行�����ΜO�賢�雿��?
# 247       ���      200810  22:36      ����啜��曉��湔�閮芸����2閮���剜�畾箸香
# 286       ���       13199  21:10          ����祆�颲��瘥��撠潦��詨���艇撣�
# 334       ���       86155  20:10         ����啜��踹�韏唬�嚗����之鈭箏��哨�
# 404       ���       17554  18:39       3D������敶梢�����扯�蝬脰楝�乩噩撌亙�
# 456       憡��      214035  17:30         憟喟��曇�憍瑕援憯��甇∪��������嗚�
# 460       �啁�       11574  17:29                撟暹革���摮�撞��翰嚗�
# 481       ��暑      173451  17:15       瘜Ｗ����銵���������祉��亦�A�����
# ...

# %%
print len(newsary)
# Out:
# 571

# %%
dic = {'a':1, 'b':2}
print dic
dic['c'] = 3
print dic
# Out:
# {'a': 1, 'b': 2}
# {'a': 1, 'c': 3, 'b': 2}

# %%
for newsdic in newsary[1:3]:
    res = requests.get(newsdic['url'])
    soup = BeautifulSoup(res.text)
    #print newsdic
    #print soup.select('#summary')[0].text
    newsdic['summary'] = soup.select('#summary')[0].text
    #print newsdic

# %%
import requests
import json
ACCESSTOKEN = '<TOKEN>'
GRAPHURL = 'https://graph.facebook.com/v2.4/898892746826726/comments?access_token={0}&fields=id%2C%20comments%2C%20message&format=json&limit=200&method=get&pretty=0&suppress_http_code=1'
res = requests.get(GRAPHURL.format(ACCESSTOKEN))
jd = json.loads(res.text)
for m in jd['data']:
    if 'message' in m:
        print m['message']
    if 'comments' in m:
        for comments in m['comments']['data']:
            print comments['message']
# Out:
# 不然要拿金馬影后舒淇露陰穴(谷歌就找得到)的照片當封面嗎?
# 拿A片當封面,哈哈哈,真的不要質疑柯P的娛樂效果 !!!!
# 我覺得找av女優來代言 只要不露點是沒差。但北市政府也太懶了吧? 都付了代言費跟權利金，重拍一張很困難嗎? 如果當初有重拍宣傳照，甚至把台北101跟波多野一起拍進去不是更符合宣傳意義?
#
# 也不會有現在的爭議。 連日本動漫周邊商都知道重畫一張插圖，賣周邊會比較好賣，悠遊卡部門的人到底在想甚麼?
# 『了解洪秀柱』
# 發現洪秀柱，了解洪秀，觀察洪秀柱，支持洪秀柱。洪秀柱必須增加和網路媒體的互動力量, 讓民眾都能碰觸到洪秀柱，體驗洪秀柱，明白洪秀柱。這一步相當重要，千萬不可忽略了年輕投票族群中偏綠的結構，如何讓選民客觀地發現台灣真正缺少哪些? 例如，和平、開放、均富、道德等，如此才能讓更多的人堅定挺住、熱情擁柱或轉向投柱。  http://blog.udn.com/alexlee668/27700515
# 為什麼只顧男性福利? 為什麼封面不是台灣藝人?請愛用國貨好嗎?
# 在捷運車內鹹豬手案例要昇高了！
# 一堆人假掰小題大作
# 不過就是用名人肖像來推廣卡片
# 衝高卡片發行量而已
# 又沒露點也有意見喔?
# ㄚ有說同一張相片不能用在別處地方?
# 好吧你說台灣保守,左邊白色那張露太多
# 那就換一張不要漏那麼多的就好了吧?
# 正面穿比基尼呢?或正面連身泳裝呢?還是正面OL裝?
# 都規規矩矩的站姿就好,不用想太多!!
# 不然用她騎U-bike的那張也OK吧?
# 大驚小怪,只有不健康的的才會往壞的方向想!!管太多!!
# 其實找SABINA 應該比較好，也是台灣捧紅的宅男女神，銷量應該也不差，但肯定沒波多野好。
# 還買得到嗎?!
# 絕對升值！
# 有沒有侵權的問題啊?
# 不太適合 是真的
# 也不過是個女優，重點是很漂亮，讓人賞心悅目，那些白痴罵什麼？逢柯必反，死藍蟲！
# 其實要跟日本av合作 推在日本發行av油油卡 幻想是殘酷
# 別罵了,今天秀柱也上了電影海報......
# 限量是殘酷的，幹我超想要！
# paging
# data
# 小朋友說這姐姐好漂亮，要去google看看
# 台灣就是艾賈先...不好色能生出你妳?
# 噁爛……！
# paging
# data
# ...

# %%
import requests
import json
APP_ID = '<APPID>'
APP_SECRET = '<APPSECRET>'
ACCESSTOKEN = '%s|%s'%(APP_ID,APP_SECRET)
GRAPHURL = 'https://graph.facebook.com/v2.4/898892746826726/comments?access_token={0}&fields=id%2C%20comments%2C%20message&format=json&limit=200&method=get&pretty=0&suppress_http_code=1'
res = requests.get(GRAPHURL.format(ACCESSTOKEN))
jd = json.loads(res.text)
for m in jd['data']:
    if 'message' in m:
        print m['message']
    if 'comments' in m:
        for comments in m['comments']['data']:
            print comments['message']
# Out:
# 不然要拿金馬影后舒淇露陰穴(谷歌就找得到)的照片當封面嗎?
# 拿A片當封面,哈哈哈,真的不要質疑柯P的娛樂效果 !!!!
# 我覺得找av女優來代言 只要不露點是沒差。但北市政府也太懶了吧? 都付了代言費跟權利金，重拍一張很困難嗎? 如果當初有重拍宣傳照，甚至把台北101跟波多野一起拍進去不是更符合宣傳意義?
#
# 也不會有現在的爭議。 連日本動漫周邊商都知道重畫一張插圖，賣周邊會比較好賣，悠遊卡部門的人到底在想甚麼?
# 『了解洪秀柱』
# 發現洪秀柱，了解洪秀，觀察洪秀柱，支持洪秀柱。洪秀柱必須增加和網路媒體的互動力量, 讓民眾都能碰觸到洪秀柱，體驗洪秀柱，明白洪秀柱。這一步相當重要，千萬不可忽略了年輕投票族群中偏綠的結構，如何讓選民客觀地發現台灣真正缺少哪些? 例如，和平、開放、均富、道德等，如此才能讓更多的人堅定挺住、熱情擁柱或轉向投柱。  http://blog.udn.com/alexlee668/27700515
# 為什麼只顧男性福利? 為什麼封面不是台灣藝人?請愛用國貨好嗎?
# 在捷運車內鹹豬手案例要昇高了！
# 一堆人假掰小題大作
# 不過就是用名人肖像來推廣卡片
# 衝高卡片發行量而已
# 又沒露點也有意見喔?
# ㄚ有說同一張相片不能用在別處地方?
# 好吧你說台灣保守,左邊白色那張露太多
# 那就換一張不要漏那麼多的就好了吧?
# 正面穿比基尼呢?或正面連身泳裝呢?還是正面OL裝?
# 都規規矩矩的站姿就好,不用想太多!!
# 不然用她騎U-bike的那張也OK吧?
# 大驚小怪,只有不健康的的才會往壞的方向想!!管太多!!
# 其實找SABINA 應該比較好，也是台灣捧紅的宅男女神，銷量應該也不差，但肯定沒波多野好。
# 還買得到嗎?!
# 絕對升值！
# 有沒有侵權的問題啊?
# 不太適合 是真的
# 也不過是個女優，重點是很漂亮，讓人賞心悅目，那些白痴罵什麼？逢柯必反，死藍蟲！
# 其實要跟日本av合作 推在日本發行av油油卡 幻想是殘酷
# 別罵了,今天秀柱也上了電影海報......
# 限量是殘酷的，幹我超想要！
# 有限量，趕鈴羊欸，難買。
# 小朋友說這姐姐好漂亮，要去google看看
# 台灣就是艾賈先...不好色能生出你妳?
# 噁爛……！
# 沒有美感！
# ...

# %%
import requests
import json
URL = 'http://www.appledaily.com.tw/realtimenews/article/new/20150826/678267/'
GRAPHURL = r'https://graph.facebook.com/v2.4/{0}?access_token={1}&fields=og_object%7Bid%2Ccomments%7Bid%2C%20message%2Cfrom%2C%20created_time%2C%20comments%7D%7D'
APP_SECRET = '1639da0d9b0315478acce4473d0e5358'
APP_ID = '714621692001049'
APP_TOKEN = '{0}|{1}'.format(APP_ID, APP_SECRET) 
res = requests.get(GRAPHURL.format(URL, APP_TOKEN))
jd = json.loads(res.text)
dtarray = []
import pandas as pd
#print jd
for comment in jd['og_object']['comments']['data']:
    dtarray.append( {'name':comment['from']['name'], \
                     'created_time':comment['created_time'], \
                     'message':comment['message']})
posts_df = pd.DataFrame(dtarray)
posts_df
# Out:
# C:\Python27\lib\site-packages\requests\packages\urllib3\util\ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
#                 created_time  \
# 0   2015-08-27T05:27:53+0000
# 1   2015-08-27T04:37:20+0000
# 2   2015-08-27T03:53:46+0000
# 3   2015-08-27T01:44:07+0000
# 4   2015-08-27T01:37:38+0000
# 5   2015-08-26T23:21:35+0000
# 6   2015-08-26T19:06:43+0000
# 7   2015-08-26T18:01:45+0000
# 8   2015-08-26T16:13:40+0000
# 9   2015-08-26T15:45:58+0000
# 10  2015-08-26T15:39:21+0000
# 11  2015-08-26T15:19:01+0000
# 12  2015-08-26T15:07:23+0000
# 13  2015-08-26T15:05:18+0000
# 14  2015-08-26T14:16:07+0000
# 15  2015-08-26T13:26:05+0000
# 16  2015-08-26T13:21:03+0000
# 17  2015-08-26T13:17:21+0000
# ...

# %%
# -*- coding: utf-8 -*- 
import sqlite3

db = sqlite3.connect('news.db') 
cur = db.cursor()
cur.execute('''DROP TABLE IF EXISTS news_entry''')
cur.execute('''CREATE TABLE IF NOT EXISTS news_entry(
                id INTEGER PRIMARY KEY,
                category TEXT,
                popularity INTEGER,
                time VARCHAR(32),
                title VARCHAR(256),
                summary TEXT,
                url VARCHAR(1024)
                )''')
cur.close()

# %%
for newsdic in newsary:
    res = requests.get(newsdic['url'])
    soup = BeautifulSoup(res.text)
    newsdic['summary'] = soup.select('#summary')[0].text
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-24-e870c4a1c10a> in <module>()
#       1 for newsdic in newsary:
# ----> 2     res = requests.get(newsdic['url'])
#       3     soup = BeautifulSoup(res.text)
#       4     newsdic['summary'] = soup.select('#summary')[0].text
#
# C:\Python27\lib\site-packages\requests\api.pyc in get(url, params, **kwargs)
#      67
#      68     kwargs.setdefault('allow_redirects', True)
# ---> 69     return request('get', url, params=params, **kwargs)
#      70
#      71
#
# C:\Python27\lib\site-packages\requests\api.pyc in request(method, url, **kwargs)
#      48
#      49     session = sessions.Session()
# ---> 50     response = session.request(method=method, url=url, **kwargs)
#      51     # By explicitly closing the session, we avoid leaving sockets open which
# ...

# %%
#print len(newsary)
#print newsary[0]
# insert into table(column1, column2) values(val1, val2);
# insert into table(column1, column2) values(?, ?);
print newsary[0].keys()
print ', '.join(newsary[0].keys())
colname = ', '.join(newsary[0].keys())
print ','.join('?' *len(newsary[0]))

#for news in newsary:
# Out:
# ['category', 'title', 'url', 'popularity', 'summary', 'time']
# category, title, url, popularity, summary, time
# ?,?,?,?,?,?

# %%
db = sqlite3.connect('news.db') 
cur = db.cursor()

for news in newsary:
    col = ', ' .join(news.keys())
    val = ','.join('?'* (len(news.keys())))
    sql = 'insert into news_entry(%s) values(%s)'%(col, val)
    cur.execute(sql,news.values())
    db.commit()
          
cur.close()
db.close()

# %%
db = sqlite3.connect('news.db') 
cur = db.cursor()
cur.execute('select * from news_entry')
allNews = cur.fetchall()
for rec in allNews:
    print rec[0], rec[1], rec[2], rec[3], rec[4]
cur.close()
db.close()
# Out:
# 1 社會 0 14:56 收50億房產　兒竟不給癱父零用錢
# 2 論壇 0 14:55 AV女優悠遊卡可以休矣！
# 3 生活 23734 14:54 【更新】南投縣竹山鎮、台北文山區　2級淹...
# 4 特企 23734 14:54 【更新】南投縣竹山鎮、台北文山區　2級淹...
# 5 社會 2971 14:50 【更新】遇上吸血鬼　他帶兒子求警「抓鬼」
# 6 社會 44 14:50 「抓耙子」的下場　刀槍棍自已選一樣
# 7 國際 56 14:49 狼犬淋雨等主人　好心路人幫撐傘
# 8 社會 14595 14:48 【更新】虐死高中生判13年　日月明功教主...
# 9 財經 51708 14:48 【更新】陸股急拉漲逾4%　3000點失而...
# 10 社會 3359 14:48 【更新】衝不出封鎖線　毒蟲被逮連累女友
# 11 生活 0 14:48 悠遊卡發行AV女優版　議員：戴季全下台！
# 12 社會 6286 14:47 偷35萬金條躲摩鐵　笨賊退房忘了拿
# 13 社會 5527 14:46 【更新】警方破獲販毒集團　緝獲槍毒逮8人
# 14 國際 653 14:42 假助學真性侵　色魔：先搞定班長上了5女童
# 15 體育 443 14:42  克拉克森打亞錦賽？老爸出面喊NO
# 16 地產 128 14:41 港墘站店面降租　本周五再度開標
# 17 生活 99 14:41 次青少棒三連霸　小英雄台中遊街
# 18 社會 1783 14:40 國道出現大水桶　駕駛ＧＧ了
# 19 生活 1185 14:37 【更新】不只畫作　米飛兔展公仔遭戳出「愛...
# 20 地產 328 14:37 夢幻貴婦藝廊　千萬收藏大公開
# 21 生活 55 14:37 台灣網民達1883萬人　18~30歲全上...
# 22 生活 478 14:30 【今周刊】被火紋身的女孩，不一樣的人生
# 23 瘋啥 1523 14:30 【今周刊】蘋果變心染紅 台灣經濟命脈瀕危
# 24 娛樂 1219 14:30 女神曾莞婷入行17年　嘆沒份報名金鐘
# 25 國際 1908 14:29 天津爆炸啟動究責　一處長墜樓身亡
# 26 國際 2566 14:27 【兇手起底】CNN：槍手與受害者有過節
# ...

# %%
input_sentence='那我們酸民婉君也可以報名嗎'

sentence  = input_sentence.decode('utf-8')

for i in range(0, len(sentence) - 2 + 1):
    print sentence[i:i+2]
# Out:
# 那我
# 我們
# 們酸
# 酸民
# 民婉
# 婉君
# 君也
# 也可
# 可以
# 以報
# 報名
# 名嗎

# %%
input_sentence='那我們酸民婉君也可以報名嗎'

sentence  = input_sentence.decode('utf-8')

for i in range(0, len(sentence) - 3 + 1):
    print sentence[i:i+3]
# Out:
# 那我們
# 我們酸
# 們酸民
# 酸民婉
# 民婉君
# 婉君也
# 君也可
# 也可以
# 可以報
# 以報名
# 報名嗎

# %%
def ngram(input_sentence, n = 2):
    word_dic = {}
    sentence  = input_sentence.decode('utf-8')
    for i in range(0, len(sentence) - n + 1):
        if sentence[i:i+n] not in word_dic:
            word_dic[sentence[i:i+n]] = 1
        else:
            word_dic[sentence[i:i+n]] = word_dic[sentence[i:i+n]] + 1
    return word_dic
for ele in ngram(input_sentence):
        print ele
# Out:
# 我們
# 婉君
# 報名
# 們酸
# 可以
# 名嗎
# 君也
# 也可
# 民婉
# 那我
# 酸民
# 以報

# %%
sentence = '123?!123125454!'
skip_word = ',@#$#^^&.?!'
len([word for word in sentence if word in skip_word]) > 0

#for word in sentence:
#    if word not in skip_word:
#        print word
# Out:
# True

# %%
for word in ngram('那我們酸民婉君也可以報名嗎?' ,n=3):
    print word
# Out:
# 酸民婉
# 君也可
# 名嗎?
# 可以報
# 也可以
# 們酸民
# 以報名
# 民婉君
# 報名嗎
# 那我們
# 婉君也
# 我們酸

# %%
skip_dic = '?.,、　「！】？：《」》～【'.decode('utf-8')
def ngram(input_sentence, n = 2, skip_word= skip_dic):
    word_dic = {}
    sentence  = input_sentence.decode('utf-8')
    for i in range(0, len(sentence) - n + 1):
        invalid = len([word for word in sentence[i:i+n] if word in skip_word])
        if sentence[i:i+n] not in word_dic and invalid ==0:
            word_dic[sentence[i:i+n]] = 1
        elif invalid ==0:
            word_dic[sentence[i:i+n]] = word_dic[sentence[i:i+n]] + 1
    return word_dic

# %%
skip_dic = '?.,、　「！】？：《」》～【'.decode('utf-8')
for word in ngram('那我們酸民婉君也可以報名嗎?' ,n=3, skip_word= skip_dic):
    print word
# Out:
# 酸民婉
# 君也可
# 可以報
# 也可以
# 們酸民
# 以報名
# 民婉君
# 報名嗎
# 那我們
# 婉君也
# 我們酸

# %%
db = sqlite3.connect('news.db') 
cur = db.cursor()
cur.execute('select * from news_entry')
allNews = cur.fetchall()
dic = {}
for rec in allNews:
    ngram_dic = ngram(rec[4].encode('utf-8'))
    for ele in ngram_dic:
        if ele not in dic:
            dic[ele] = ngram_dic[ele]
        else:
            dic[ele] = dic[ele] + ngram_dic[ele]
cur.close()
db.close()

# %%
#for ele in dic:
#    print ele, dic[ele]

import operator
words_freq = sorted(dic.iteritems(),key=operator.itemgetter(1),reverse=True)
for ele in words_freq[0:10]:
    print ele[0], ele[1]
# Out:
# 更新 49
# 悠遊 19
# 多野 19
# 波多 19
# 遊卡 19
#    17
# 台灣 16
# 00 15
# 法廣 13
# RF 13

# %%
db = sqlite3.connect('news.db') 
cur = db.cursor()
cur.execute('select * from news_entry')
allNews = cur.fetchall()
dic = {}
for rec in allNews:
    ngram_dic = ngram(rec[4].encode('utf-8'), n=3)
    for ele in ngram_dic:
        if ele not in dic:
            dic[ele] = ngram_dic[ele]
        else:
            dic[ele] = dic[ele] + ngram_dic[ele]
cur.close()
db.close()


import operator
words_freq = sorted(dic.iteritems(),key=operator.itemgetter(1),reverse=True)
for ele in words_freq[0:10]:
    print ele[0], ele[1]
# Out:
# 悠遊卡 19
# 波多野 19
# 廣RF 13
# 法廣R 13
# RFI 13
# 多野結 8
# 野結衣 8
# AV女 8
# V女優 8
# 多野悠 7

# %%
import requests
from bs4 import BeautifulSoup as bs
res = requests.get('http://www.taiwantrade.com.tw/MAIN/ProductSch.do?method=doSch&schType=7&categoryId6=421110&locale=2&fromCategory=y&seoCategoryId=42&categoryId=4211&linkId=11555')
soup = bs(res.text)
domain = 'http://www.taiwantrade.com.tw/MAIN/ProductSch.do?'
for inp in  soup.select('#productForm input'):
    if inp.get('value') is not None:
        if inp.get('name') is not None and inp.get('value') is not None:                       
            print "{0}={1}".format(inp.get('name'), inp.get('value'))
            #print a, inp.get('value')
#print domain.strip('&')
# Out:
# cs_allWord=
# suppliersQueryCondition=
# dunsQueryCondition=cs_allWord=dreall,csr_fieldName=CERT_TYPE,cs_categoryId6=421110,cs_combine=simple,templateId=54A11F9E326B0A77E044000C296C8530,idolApiAction=CategoryService
# categoryQueryCondition=cs_allWord=dreall,csr_fieldName=CATEGORY_ID_NAME,cs_categoryId6=421110,cs_combine=simple,templateId=54A11F9E326B0A77E044000C296C8530,idolApiAction=CategoryService
# businessTypeQueryCondition=
# bizTypeQueryCondition=
# listQueryCondition=cs_start=1,cs_end=10,cs_sort=MEMBER_TYPE%2CIS_SELL,cs_sortMethod=101%2C101,cs_allWord=dreall,cs_categoryId6=421110,cs_requestUser=172.20.1.158,cs_combine=simple,storeState=true,templateId=55AAC836033F4686A1A0ECE955C8B234,idolApiAction=TemplateService
# productQueryCondition=
# catalogQueryCondition=
# sampleQueryCondition=
# bizExchangeQueryCondition=
# newsQueryCondition=
# eventQueryCondition=
# companyQueryCondition=
# recmdQueryCondition=
# pageNo=1
# pageSize=10
# ascOrder=
# descOrder=
# method=doSch
# ...

# %%
link = 'http://www.taiwantrade.com.tw/MAIN/ProductSch.do?cs_allWord=&dunsQueryCondition=cs_allWord%3Ddreall%2Ccsr_fieldName%3DCERT_TYPE%2Ccs_categoryId6%3D421110%2Ccs_combine%3Dsimple%2CtemplateId%3D54A11F9E326B0A77E044000C296C8530%2CidolApiAction%3DCategoryService&categoryQueryCondition=cs_allWord%3Ddreall%2Ccsr_fieldName%3DCATEGORY_ID_NAME%2Ccs_categoryId6%3D421110%2Ccs_combine%3Dsimple%2CtemplateId%3D54A11F9E326B0A77E044000C296C8530%2CidolApiAction%3DCategoryService&listQueryCondition=cs_start%3D1%2Ccs_end%3D10%2Ccs_sort%3DMEMBER_TYPE%252CIS_SELL%2Ccs_sortMethod%3D101%252C101%2Ccs_allWord%3Ddreall%2Ccs_categoryId6%3D421110%2Ccs_requestUser%3D172.20.1.158%2Ccs_combine%3Dsimple%2CstoreState%3Dtrue%2CtemplateId%3D55AAC836033F4686A1A0ECE955C8B234%2CidolApiAction%3DTemplateService&pageNo=2&pageSize=10&method=doSch&schType=1&totalCount=35&showType=0&searchState=productSearch&isOtherSearch=&categoryId6=421110&fromCategory=y&seoCategoryId=42&categoryId=4211&linkId=11555&cs_stateId=E1%3A053RKSRJEQVM-35&setLangCode=en&dunsId=&rf_categoryId='
dic ={}
for ele in link.split('?')[1].split('&'):
    n = ele.split('=')
    print "{0}={1}".format(n[0], n[1])
# Out:
# cs_allWord=
# dunsQueryCondition=cs_allWord%3Ddreall%2Ccsr_fieldName%3DCERT_TYPE%2Ccs_categoryId6%3D421110%2Ccs_combine%3Dsimple%2CtemplateId%3D54A11F9E326B0A77E044000C296C8530%2CidolApiAction%3DCategoryService
# categoryQueryCondition=cs_allWord%3Ddreall%2Ccsr_fieldName%3DCATEGORY_ID_NAME%2Ccs_categoryId6%3D421110%2Ccs_combine%3Dsimple%2CtemplateId%3D54A11F9E326B0A77E044000C296C8530%2CidolApiAction%3DCategoryService
# listQueryCondition=cs_start%3D1%2Ccs_end%3D10%2Ccs_sort%3DMEMBER_TYPE%252CIS_SELL%2Ccs_sortMethod%3D101%252C101%2Ccs_allWord%3Ddreall%2Ccs_categoryId6%3D421110%2Ccs_requestUser%3D172.20.1.158%2Ccs_combine%3Dsimple%2CstoreState%3Dtrue%2CtemplateId%3D55AAC836033F4686A1A0ECE955C8B234%2CidolApiAction%3DTemplateService
# pageNo=2
# pageSize=10
# method=doSch
# schType=1
# totalCount=35
# showType=0
# searchState=productSearch
# isOtherSearch=
# categoryId6=421110
# fromCategory=y
# seoCategoryId=42
# categoryId=4211
# linkId=11555
# cs_stateId=E1%3A053RKSRJEQVM-35
# ...

# %%
import re
delimiter = "，|。|、"  
text = '3年前就讀高雄應用大學二年級的陳顯佳，為閃避跨越雙黃線來車，撞上路邊、摔斷頸椎，頸部以下全癱，嘴被插管，父母每天去看他，他都意識清醒、眨眼流淚，17天後他因頸椎受損抑制呼吸，醫師用盡強力針與電擊都無效，'
for i in re.split(delimiter, text):
    print i
# Out:
# 3年前就讀高雄應用大學二年級的陳顯佳
# 為閃避跨越雙黃線來車
# 撞上路邊
# 摔斷頸椎
# 頸部以下全癱
# 嘴被插管
# 父母每天去看他
# 他都意識清醒
# 眨眼流淚
# 17天後他因頸椎受損抑制呼吸
# 醫師用盡強力針與電擊都無效

# %%
a = '民進黨後天將公布'
#for ele in a.split('後天'):
#    print ele
    
#print ''.join(a.split('後天'))

dic = ['民進黨', '後天']
for ele in dic:
    if ele in a:
        a = ''.join(a.split(ele))
print a
# Out:
# 將公布

# %%
def removeKey(text, keyword):
    textAry= text
    for key in keyword:
        textAry = ''.join(textAry.split(key))
    return textAry

# %%
db = sqlite3.connect('news.db') 
cur = db.cursor()
cur.execute('select * from news_entry')
allNews = cur.fetchall()
sentenceAry = []
for rec in allNews:
    sentenceAry.append(rec[4].encode('utf-8'))

# %%
keywords=['波多野悠遊卡']        
ret_terms={}
words_freq    = []
for term_length in range(5,1,-1):
    word_dic = {}
    for sentence in sentenceAry:
        text_list = removeKey(sentence,keywords)        
        ngram_words = ngram(text_list,term_length) 
        for word in ngram_words:
            if word not in word_dic:
                word_dic[word] = 1
            else:
                word_dic[word] += ngram_words[word]   
    for word in word_dic:
        if word_dic[word] >= 5:
            keywords.append(word.encode('utf-8'))            
            ret_terms.update({word:word_dic[word]})

for ele in ret_terms:
    print ele, ret_terms[ele]
# Out:
# 少女 6
# 30 5
# 北市 5
# 美記者 6
# 直擊 5
# 40 5
# 0億 5
# 柯P 6
# 20 7
# 悠遊卡 12
# 80 5
# 食品 5
# 國道 5
# 00 14
# 連戰 8
# 閱兵 11
# 60 6
# 曝光 8
# 募兵 5
# 北京 5
# 8億 5
# 市場 5
# 釣魚 5
# 的人 5
# 時代 6
# 處理 5
# 網友 13
# 0萬 10
# 民報 5
# 台灣 16
#    17
# 台北 6
# AV女優 8
# 億元 5
# 中國 9
# 民眾 8
# 0元 5
# 影片 6
# 股價 6
# 經濟 6
# 記者 6
# 波多野結衣 8
# 槍手 6
# 大雨 5
# 11 5
# 10 12
# 13 5
# 15 5
# 0年 5
# 17 5
# 18 10
# 代言 5
# 公庫 5
# 更新 49
# 槍擊 6
# 法廣RFI 13
# 自拍 6
# 國民 5
# 台股 5
# 金鐘 5
# 這樣 6
# 什麼 7
